# %% [markdown]
# <a href="https://colab.research.google.com/github/NishantShokeen/RL/blob/main/experiment2(part1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x= np.random.randint(0,50,1000)
y= x + np.random.normal(0,10,1000)

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.81257361],
#        [0.81257361, 1.        ]])

# %%
Oplt.scatter (x,y)
plt.show()

# %% [markdown]
# Positive corelation between x and y shown in the scatter plot above

# %%
y= 100-(x + np.random.normal(0,10,1000))

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.81586145],
#        [-0.81586145,  1.        ]])

# %%
plt.scatter (x,y)
plt.show()

# %% [markdown]
# Negative corelation between x and y shown in the scatter plot above

# %%
x= np.random.randint(0,50,1000)
y= np.random.randint(0,10,1000)

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.03849039],
#        [-0.03849039,  1.        ]])

# %%
plt.scatter (x,y)
plt.show()

# %%
df = pd.DataFrame({'a': np.random.randint(0, 50, 1000)})

df['b'] = df['a']+ np.random.normal(0, 10, 1000)

df['c']= 100-df['a']+ np.random.normal(0, 50, 1000)

df ['d']= np.random.randint(0, 50, 1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.821791 -0.254659 -0.037019
# b  0.821791  1.000000 -0.194217 -0.027430
# c -0.254659 -0.194217  1.000000  0.015408
# d -0.037019 -0.027430  0.015408  1.000000

# %%
pd.plotting.scatter_matrix(df,figsize=[6,6])
plt.show()

# %%
plt.matshow(df.corr())

plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
